# %%
import sys
import pandas as pd 
import numpy as np 
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score, recall_score, precision_score, f1_score, accuracy_score

# %%
# VARS 

PATH = '.\\data\\' if sys.platform == 'win32' else './data/'
SOLUTIONS = '.\\submissions\\' if sys.platform == 'win32' else './submissions/'

# %%
train_df = pd.read_csv(
    PATH + 'prepared_df.csv',
    index_col=0,
    dtype={
        'PATIENT_SEX':str, 
        'MKB_CODE':str, 
        'ADRES':str, 
        'VISIT_MONTH_YEAR':str, 
        'AGE_CATEGORY':str, 
        'PATIENT_ID_COUNT':int}
        )

# %%
train_df.DATE = pd.to_datetime(train_df.DATE)

# %%
train_df.sort_values(by='DATE').reset_index(drop=True)
# Out:
#         PATIENT_SEX        ADRES MKB_CODE CHAPTER AGE_CATEGORY  MONTH  YEAR  \
# 0              Male  Комсомольск    Z01.7     XXI         0-18      1  2018
# 1              Male  Калининград    E27.8      IV        18-44      1  2018
# 2            Female   Пионерский      C34      II        75-90      1  2018
# 3              Male  Калининград    S62.6     XIX        60-74      1  2018
# 4              Male  Калининград    E27.8      IV        60-74      1  2018
# ...             ...          ...      ...     ...          ...    ...   ...
# 2212388      Female        Гусев      J20       X        60-74      3  2022
# 2212389      Female     Балтийск      J20       X        75-90      3  2022
# 2212390      Female     Балтийск      J20       X         0-18      3  2022
# 2212391      Female  Калининград      J20       X        45-59      3  2022
# 2212392      Female      Советск    N85.9     XIV        60-74      3  2022
#
#               DATE  IS_COVID  PATIENT_ID_COUNT TARGET_RANGE
# 0       2018-01-01     False                 2         1-10
# 1       2018-01-01     False                 1         1-10
# 2       2018-01-01     False                 1         1-10
# 3       2018-01-01     False                 5         1-10
# 4       2018-01-01     False                 1         1-10
# ...            ...       ...               ...          ...
# 2212388 2022-03-01      True                 2         1-10
# 2212389 2022-03-01      True                 1         1-10
# 2212390 2022-03-01      True                 3         1-10
# 2212391 2022-03-01      True                 1         1-10
# 2212392 2022-03-01      True                 1         1-10
#
# [2212393 rows x 11 columns]

# %%
g = train_df.groupby(pd.Grouper(key='DATE', freq='M'))

# %%
dfs = [group for _,group in g]

# %%
dfs[0].reset_index(drop=True)
# Out:
#       PATIENT_SEX                     ADRES MKB_CODE CHAPTER AGE_CATEGORY  \
# 0          Female               Калининград    A02.0       I         0-18
# 1          Female               Калининград    A02.0       I        60-74
# 2          Female               Калининград    A02.0       I        18-44
# 3          Female  СТ Искра ул. Тюльпановая    A02.0       I         0-18
# 4          Female               Калининград      A02       I         0-18
# ...           ...                       ...      ...     ...          ...
# 50765        Male               Калининград    Z98.8     XXI        18-44
# 50766        Male                Прибрежный    Z98.8     XXI        45-59
# 50767        Male                  Приморье    Z98.8     XXI        45-59
# 50768        Male               Светлогорск    Z98.8     XXI        60-74
# 50769        Male               Светлогорск    Z98.8     XXI        45-59
#
#        MONTH  YEAR       DATE  IS_COVID  PATIENT_ID_COUNT TARGET_RANGE
# 0          1  2018 2018-01-01     False                 3         1-10
# 1          1  2018 2018-01-01     False                 1         1-10
# 2          1  2018 2018-01-01     False                 2         1-10
# 3          1  2018 2018-01-01     False                 1         1-10
# 4          1  2018 2018-01-01     False                 1         1-10
# ...      ...   ...        ...       ...               ...          ...
# 50765      1  2018 2018-01-01     False                 2         1-10
# 50766      1  2018 2018-01-01     False                 1         1-10
# 50767      1  2018 2018-01-01     False                 1         1-10
# 50768      1  2018 2018-01-01     False                 3         1-10
# 50769      1  2018 2018-01-01     False                 2         1-10
#
# [50770 rows x 11 columns]

# %%
model = CatBoostRegressor(
    task_type='GPU',
    random_state=42,
    early_stopping_rounds=20
)

# %%
for index, dataframe in enumerate(dfs, start=1):
    
    try:
        traindf = pd.concat(dfs[:index])
        testdf = dfs[index]
    except:
        traindf = dataframe
    
    X_train = traindf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_train = traindf.PATIENT_ID_COUNT
    X_test = testdf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_test = testdf.PATIENT_ID_COUNT

    pool_train = Pool(X_train, y_train, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])
    pool_test = Pool(X_test, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])

    model.fit(pool_train, silent=True)

    y_pred = model.predict(pool_test)
    y_pred = [1 if value <= 0 else int(value) for value in y_pred]
    
    
    print(f'fold {index}')
    print('R2: ', r2_score(y_test, y_pred))
    print('#'*50)
# Out:
# fold 1
# R2:  0.9096895612552429
# ##################################################
# fold 2
# R2:  0.9507799439096344
# ##################################################
# fold 3
# R2:  0.9087663701399205
# ##################################################
# fold 4
# R2:  0.7577398013651049
# ##################################################
# fold 5
# R2:  0.8851970524582206
# ##################################################
# fold 6
# R2:  0.9271653899927161
# ##################################################
# fold 7
# R2:  0.9016627279788647
# ##################################################
# fold 8
# R2:  0.8676108639181367
# ##################################################
# fold 9
# R2:  0.8899388205706918
# ##################################################
# fold 10
# R2:  0.9393393709243315
# ##################################################
# fold 11
# R2:  0.9296665773640801
# ##################################################
# fold 12
# R2:  0.8393100232777904
# ##################################################
# fold 13
# R2:  0.9241648163633188
# ##################################################
# fold 14
# R2:  0.8351520462187205
# ##################################################
# fold 15
# R2:  0.9169059520762994
# ##################################################
# fold 16
# R2:  0.9415051678852218
# ##################################################
# fold 17
# R2:  0.9353393384247881
# ##################################################
# fold 18
# R2:  0.9178566181951605
# ##################################################
# fold 19
# R2:  0.8913905924910118
# ##################################################
# fold 20
# R2:  0.9107056197939233
# ##################################################
# fold 21
# R2:  0.9465292084781344
# ##################################################
# fold 22
# R2:  0.9255541437771193
# ##################################################
# fold 23
# R2:  0.9533643087400661
# ##################################################
# fold 24
# R2:  0.6949509612642091
# ##################################################
# fold 25
# R2:  0.8687231695599704
# ##################################################
# fold 26
# R2:  0.8749330980441468
# ##################################################
# fold 27
# R2:  -1.7908248345433417
# ##################################################
# fold 28
# R2:  0.3345349937584723
# ##################################################
# fold 29
# R2:  0.5455896707670126
# ##################################################
# fold 30
# R2:  0.7295119423507088
# ##################################################
# fold 31
# R2:  0.841982273901746
# ##################################################
# fold 32
# R2:  0.8726810752500933
# ##################################################
# fold 33
# R2:  0.8781333372807991
# ##################################################
# fold 34
# R2:  0.7592993850545742
# ##################################################
# fold 35
# R2:  0.869091490170539
# ##################################################
# fold 36
# R2:  0.5964123179513662
# ##################################################
# fold 37
# R2:  0.6227614401933804
# ##################################################
# fold 38
# R2:  0.6595204860742645
# ##################################################
# fold 39
# R2:  0.6525691701947278
# ##################################################
# fold 40
# R2:  0.8644080047040251
# ##################################################
# fold 41
# R2:  0.8202674470289338
# ##################################################
# fold 42
# R2:  0.7755168893712195
# ##################################################
# fold 43
# R2:  0.8621933760301237
# ##################################################
# fold 44
# R2:  0.6545736956832129
# ##################################################
# fold 45
# R2:  0.8034230784412247
# ##################################################
# fold 46
# R2:  0.8892557577993373
# ##################################################
# fold 47
# R2:  0.7352999849468829
# ##################################################
# fold 48
# R2:  0.6471584960650607
# ##################################################
# fold 49
# R2:  0.7380218463535863
# ##################################################
# fold 50
# R2:  0.30430478554932816
# ##################################################
# fold 51
# R2:  0.676252401210163
# ##################################################

# %%
g110 = train_df[train_df.TARGET_RANGE == '1-10'].groupby(pd.Grouper(key='DATE', freq='M'))

# %%
dfs110 = [group for _,group in g110]

# %%
for index, dataframe in enumerate(dfs110, start=1):
    
    try:
        traindf = pd.concat(dfs110[:index]).reset_index(drop=True)
        testdf = dfs110[index].reset_index(drop=True)
    except:
        traindf = dataframe.reset_index(drop=True)
    
    X_train = traindf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_train = traindf.PATIENT_ID_COUNT
    X_test = testdf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_test = testdf.PATIENT_ID_COUNT

    pool_train = Pool(X_train, y_train, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])
    pool_test = Pool(X_test, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])

    print('Current test date is', testdf.MONTH[0],testdf.YEAR[0])
    model.fit(pool_train, silent=True)

    y_pred = model.predict(pool_test)
    y_pred = [1 if round(value) <= 0 else round(value) for value in y_pred]
    
    
    print(f'fold {index}')
    print('R2: ', r2_score(y_test, y_pred))
    print('#'*50)
# Out:
# Current test date is 2 2018
# fold 1
# R2:  0.3503573331837476
# ##################################################
# Current test date is 3 2018
# fold 2
# R2:  0.4117713303959133
# ##################################################
# Current test date is 4 2018
# fold 3
# R2:  0.44988181973769736
# ##################################################
# Current test date is 5 2018
# fold 4
# R2:  0.43956052611289653
# ##################################################
# Current test date is 6 2018
# fold 5
# R2:  0.4551893173499202
# ##################################################
# Current test date is 7 2018
# fold 6
# R2:  0.46109906829863867
# ##################################################
# Current test date is 8 2018
# fold 7
# R2:  0.4568410022004099
# ##################################################
# Current test date is 9 2018
# fold 8
# R2:  0.449755096705003
# ##################################################
# Current test date is 10 2018
# fold 9
# R2:  0.4694301484882559
# ##################################################
# Current test date is 11 2018
# fold 10
# R2:  0.4742917747868871
# ##################################################
# Current test date is 12 2018
# fold 11
# R2:  0.4943791911325489
# ##################################################
# Current test date is 1 2019
# fold 12
# R2:  0.470500728391132
# ##################################################
# Current test date is 2 2019
# fold 13
# R2:  0.48876966876987626
# ##################################################
# Current test date is 3 2019
# fold 14
# R2:  0.5059478846330598
# ##################################################
# Current test date is 4 2019
# fold 15
# R2:  0.4882428573355865
# ##################################################
# Current test date is 5 2019
# fold 16
# R2:  0.4857965175603487
# ##################################################
# Current test date is 6 2019
# fold 17
# R2:  0.47190415520546725
# ##################################################
# Current test date is 7 2019
# fold 18
# R2:  0.4738960741997412
# ##################################################
# Current test date is 8 2019
# fold 19
# R2:  0.47789068384304556
# ##################################################
# Current test date is 9 2019
# fold 20
# R2:  0.4854720752656616
# ##################################################
# Current test date is 10 2019
# fold 21
# R2:  0.48785092104170213
# ##################################################
# Current test date is 11 2019
# fold 22
# R2:  0.47698271555479343
# ##################################################
# Current test date is 12 2019
# fold 23
# R2:  0.4891554971752913
# ##################################################
# Current test date is 1 2020
# fold 24
# R2:  0.39554821915031024
# ##################################################
# Current test date is 2 2020
# fold 25
# R2:  0.41974445728911325
# ##################################################
# Current test date is 3 2020
# fold 26
# R2:  0.43971964211566916
# ##################################################
# Current test date is 4 2020
# fold 27
# R2:  0.1545815935928303
# ##################################################
# Current test date is 5 2020
# fold 28
# R2:  0.3718555248208729
# ##################################################
# Current test date is 6 2020
# fold 29
# R2:  0.36821946347287793
# ##################################################
# Current test date is 7 2020
# fold 30
# R2:  0.4344620813726071
# ##################################################
# Current test date is 8 2020
# fold 31
# R2:  0.4372853132064023
# ##################################################
# Current test date is 9 2020
# fold 32
# R2:  0.4404976133073353
# ##################################################
# Current test date is 10 2020
# fold 33
# R2:  0.4417287399303915
# ##################################################
# Current test date is 11 2020
# fold 34
# R2:  0.38903341358942056
# ##################################################
# Current test date is 12 2020
# fold 35
# R2:  0.4059556966891259
# ##################################################
# Current test date is 1 2021
# fold 36
# R2:  0.3582064723721927
# ##################################################
# Current test date is 2 2021
# fold 37
# R2:  0.413265709517032
# ##################################################
# Current test date is 3 2021
# fold 38
# R2:  0.43019019946735815
# ##################################################
# Current test date is 4 2021
# fold 39
# R2:  0.4502274783817657
# ##################################################
# Current test date is 5 2021
# fold 40
# R2:  0.47478517851254864
# ##################################################
# Current test date is 6 2021
# fold 41
# R2:  0.45607808506262804
# ##################################################
# Current test date is 7 2021
# fold 42
# R2:  0.4276815913427503
# ##################################################
# Current test date is 8 2021
# fold 43
# R2:  0.44934863443921336
# ##################################################
# Current test date is 9 2021
# fold 44
# R2:  0.45388362369901425
# ##################################################
# Current test date is 10 2021
# fold 45
# R2:  0.45541112219372637
# ##################################################
# Current test date is 11 2021
# fold 46
# R2:  0.46072687070929075
# ##################################################
# Current test date is 12 2021
# fold 47
# R2:  0.4380227563394756
# ##################################################
# Current test date is 1 2022
# fold 48
# R2:  0.3980303649925958
# ##################################################
# Current test date is 2 2022
# fold 49
# R2:  0.33187637286430205
# ##################################################
# Current test date is 3 2022
# fold 50
# R2:  0.4384854586661411
# ##################################################
# Current test date is 3 2022
# fold 51
# R2:  0.42337825472873525
# ##################################################

# %%
df110 = train_df[train_df.TARGET_RANGE == '1-10']

# %%
y_test_110 = df110.PATIENT_ID_COUNT
X_test_110 = df110.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)

pool_test_110 = Pool(X_test_110, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])

# %%
preds = model.predict(pool_test_110)

# %%
r2_score(y_test_110, preds)
# Out:
# 0.23502018454721507

# %%
df110['PREDS'] = preds
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df110
# Out:
#         PATIENT_SEX        ADRES MKB_CODE CHAPTER AGE_CATEGORY  MONTH  YEAR  \
# 0            Female     Гурьевск    A00.0       I        18-44      8  2021
# 1            Female  Калининград    A00.0       I         0-18      3  2020
# 2            Female        Гусев      A00       I         0-18      3  2019
# 3            Female  Калининград      A00       I         0-18      1  2022
# 4            Female  Калининград      A00       I         0-18      2  2018
# ...             ...          ...      ...     ...          ...    ...   ...
# 2212388        Male     Гурьевск    Z99.1     XXI         0-18     12  2021
# 2212389        Male  Калининград    Z99.8     XXI        18-44     10  2021
# 2212390        Male  Калининград    Z99.9     XXI         0-18      4  2019
# 2212391        Male  Калининград    Z99.9     XXI         0-18      8  2019
# 2212392        Male  Калининград    Z99.9     XXI         0-18     11  2019
#
#               DATE  IS_COVID  PATIENT_ID_COUNT TARGET_RANGE     PREDS
# 0       2021-08-01      True                 1         1-10  1.140746
# 1       2020-03-01     False                 1         1-10  1.301365
# 2       2019-03-01     False                 1         1-10  1.160958
# 3       2022-01-01      True                 1         1-10  2.310950
# 4       2018-02-01     False                 1         1-10  2.310950
# ...            ...       ...               ...          ...       ...
# 2212388 2021-12-01      True                 1         1-10  1.128315
# 2212389 2021-10-01      True                 1         1-10  1.422220
# 2212390 2019-04-01     False                 2         1-10  1.341057
# 2212391 2019-08-01     False                 1         1-10  1.341057
# 2212392 2019-11-01     False                 1         1-10  1.341057
#
# [2064557 rows x 12 columns]

# %%
df110.PATIENT_ID_COUNT.value_counts()
# Out:
# 1     1366778
# 2      318988
# 3      136250
# 4       77480
# 5       50492
# 6       36202
# 7       26606
# 8       21021
# 9       16873
# 10      13867
# Name: PATIENT_ID_COUNT, dtype: int64

# %%
df110.PREDS.value_counts()
# Out:
# 1    1158326
# 2     513933
# 3     213281
# 4     114157
# 5      44541
# 6      16246
# 7       3989
# 8         84
# Name: PREDS, dtype: int64

# %%
df110.to_csv(PATH + 'df110_boosted.csv')

# %%
g110_2 = df110.groupby(pd.Grouper(key='DATE', freq='M'))

# %%
dfs110_2 = [group for _,group in g110_2]

# %%
for index, dataframe in enumerate(dfs110_2, start=1):
    
    try:
        traindf = pd.concat(dfs110_2[:index]).reset_index(drop=True)
        testdf = dfs110_2[index].reset_index(drop=True)
    except:
        traindf = dataframe.reset_index(drop=True)
    
    X_train = traindf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_train = traindf.PATIENT_ID_COUNT
    X_test = testdf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_test = testdf.PATIENT_ID_COUNT

    pool_train = Pool(X_train, y_train, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])
    pool_test = Pool(X_test, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])

    print('Current test date is', testdf.MONTH[0],testdf.YEAR[0])
    model.fit(pool_train, silent=True)

    y_pred = model.predict(pool_test)
    y_pred = [1 if round(value) <= 0 else round(value) for value in y_pred]
    
    
    print(f'fold {index}')
    print('R2: ', r2_score(y_test, y_pred))
    print('#'*50)

# %% [markdown]
# Make a classification model

# %%
binary_classification_model = CatBoostClassifier(
    task_type='GPU',
    random_state=42,
    early_stopping_rounds=20
)

# %%
train_df['IS_1-10'] = [True if range == '1-10' else False for range in train_df.TARGET_RANGE]

# %%
g_binary = train_df[train_df.YEAR == 2022].groupby(pd.Grouper(key='DATE', freq='M'))

# %%
dfs_binary = [group for _, group in g_binary]

# %%
dfs_binary[0]['IS_1-10'].value_counts(normalize=True)
# Out:
# True     0.913375
# False    0.086625
# Name: IS_1-10, dtype: float64

# %%
for index, dataframe in enumerate(dfs_binary, start=1):
    
    try:
        traindf = pd.concat(dfs_binary[:index]).reset_index(drop=True)
        testdf = dfs_binary[index].reset_index(drop=True)
    except:
        traindf = dataframe.reset_index(drop=True)
    
    X_train = traindf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_train = traindf['IS_1-10']
    X_test = testdf.drop(['PATIENT_ID_COUNT', 'DATE', 'TARGET_RANGE', 'CHAPTER'], axis=1)
    y_test = testdf['IS_1-10']

    pool_train = Pool(X_train, y_train, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])
    pool_test = Pool(X_test, cat_features = ['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'IS_COVID'])

    print('Current test date is', testdf.MONTH[0],testdf.YEAR[0])
    binary_classification_model.fit(pool_train, silent=True)

    y_pred = binary_classification_model.predict(pool_test)
    y_pred = y_pred.astype(bool)
    print('Accuracy: ',accuracy_score(y_test, y_pred))
    print('Recall: ', recall_score(y_test, y_pred, average='binary', pos_label=True)) 
    print('Precision: ', precision_score(y_test, y_pred, average='binary', pos_label=True))
    print('F1 score: ', f1_score(y_test, y_pred, average='binary', pos_label=True))
    print('#'*50)
# Out:
# Current test date is 2 2022
# Accuracy:  0.9135452603909973
# Recall:  1.0
# Precision:  0.9135452603909973
# F1 score:  0.9548196003519993
# ##################################################
# Current test date is 3 2022
# Accuracy:  0.9041544988704612
# Recall:  1.0
# Precision:  0.9041544988704612
# F1 score:  0.9496650606941853
# ##################################################
# Current test date is 3 2022
# Accuracy:  0.9041544988704612
# Recall:  1.0
# Precision:  0.9041544988704612
# F1 score:  0.9496650606941853
# ##################################################

# %%
np.unique(y_pred)
# Out:
# array([ True])

# %% [markdown]
# Well, it doesn't work... I have to try something else soon
